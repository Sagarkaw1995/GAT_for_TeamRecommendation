# %%
import sys
sys.path.insert(0, '../dal')
import load_dblp_data as dblp

# %%
m2v_path = '../dataset/embedding_dict_gat.pkl'

# %%
preprocessed_dataset = dblp.load_preprocessed_dataset(file_path='../dataset/dblp_preprocessed_dataset.pkl')
dblp.nn_m2v_dataset_generator(model_path=m2v_path, dataset=preprocessed_dataset, output_file_path='../dataset/ae_e_m2v_tSkill_dataset.pkl', mode='skill')
# Out:
# Record #1 | File #2331 appended to dataset.
# Record #2 | File #2332 appended to dataset.
# Record #3 | File #2336 appended to dataset.
# Record #4 | File #2342 appended to dataset.
# Record #5 | File #2344 appended to dataset.
# Record #6 | File #2346 appended to dataset.
# Record #7 | File #2347 appended to dataset.
# Record #8 | File #2350 appended to dataset.
# Record #9 | File #2352 appended to dataset.
# Record #10 | File #2354 appended to dataset.
# Record #11 | File #2355 appended to dataset.
# Record #12 | File #2356 appended to dataset.
# Record #13 | File #2361 appended to dataset.
# Record #14 | File #2362 appended to dataset.
# Record #15 | File #2364 appended to dataset.
# Record #16 | File #2366 appended to dataset.
# Record #17 | File #2367 appended to dataset.
# Record #18 | File #2368 appended to dataset.
# Record #19 | File #2369 appended to dataset.
# Record #20 | File #2370 appended to dataset.
# Record #21 | File #2371 appended to dataset.
# ...

# %%
dataset = dblp.load_ae_dataset(file_path='../dataset/ae_e_m2v_tSkill_dataset.pkl')

# %%
dataset[0][1].shape
